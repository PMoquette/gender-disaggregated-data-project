# %% [markdown]
# ## Data cleaning for Syria Conflict database
#
# This dataset was found on HDX.
#
# Source:<br>
# *Remember to add to presentation!*<br>
# "Armed Conflict Location & Event Data Project (ACLED)"<br>
# [Source](acleddata.com)<br>
# [HDX Source](https://data.humdata.org/dataset/acled-data-for-syrian-arab-republic)<br>
#
# The appropriate codebook to use is: Armed Conflict Location & Event Data Project (ACLED)

# %%
import numpy as np
import pandas as pd
pd.set_option("max_r", 100)
pd.get_option("display.max_rows")
pd.options.display.max_columns = None
from textblob import TextBlob

# %%
conflict_syr = pd.read_csv('../data/HDX-data/syr/conflict_data_syr.csv',low_memory=False)

# %%
conflict_syr.head()
# Out:
#      data_id    iso event_id_cnty  event_id_no_cnty      event_date  \
# 0        NaN    NaN   #event+code               NaN  #date+occurred
# 1  6993667.0  760.0      SYR76938           76938.0      2020-03-14
# 2  6993669.0  760.0      SYR76939           76939.0      2020-03-14
# 3  6993742.0  760.0      SYR76930           76930.0      2020-03-14
# 4  6993746.0  760.0      SYR76937           76937.0      2020-03-14
#
#          year  time_precision                  event_type  \
# 0  #date+year             NaN                 #event+type
# 1        2020             1.0  Explosions/Remote violence
# 2        2020             1.0  Explosions/Remote violence
# 3        2020             1.0                     Battles
# 4        2020             1.0  Explosions/Remote violence
#
#                   sub_event_type                            actor1  \
# 0                            NaN                 #group+name+first
# 1  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)
# 2  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)
# 3                    Armed clash  Unidentified Armed Group (Syria)
# 4  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)
#
#              assoc_actor_1  inter1  \
# 0  #group+name+first+assoc     NaN
# 1                      NaN     3.0
# 2                      NaN     3.0
# 3                      NaN     3.0
# 4                      NaN     3.0
#
#                                          actor2              assoc_actor_2  \
# 0                            #group+name+second   #group+name+second+assoc
# 1                                           NaN                        NaN
# 2                                           NaN                        NaN
# 3  QSD: Syrian Democratic Forces - Intelligence                        NaN
# 4                        Operation Peace Spring  Opposition Rebels (Syria)
#
#    inter2  interaction        region        country       admin1       admin2  \
# 0     NaN          NaN  #region+name  #country+name   #adm1+name   #adm2+name
# 1     0.0         30.0   Middle East          Syria     Ar-Raqqa     Ar-Raqqa
# 2     0.0         30.0   Middle East          Syria     Ar-Raqqa     Ar-Raqqa
# 3     2.0         23.0   Middle East          Syria  Deir-ez-Zor  Deir-ez-Zor
# 4     2.0         23.0   Middle East          Syria       Aleppo       Al Bab
#
#        admin3   location  latitude longitude  geo_precision        source  \
# 0  #adm3+name  #loc+name  #geo+lat  #geo+lon            NaN  #meta+source
# 1    Ar-Raqqa   Ar-Raqqa   35.9428   39.0519            1.0          SHAM
# 2      Karama     Karama   35.8699   39.2813            2.0          SHAM
# 3      Basira     Takihi   35.1751   40.4547            2.0          SOHR
# 4    Ar-Ra'ee   Ar-Ra'ee   36.6125   37.4464            1.0          SOHR
#
#   source_scale                                              notes  \
# 0          NaN                                       #description
# 1     National  On 14 March 2020, an IED planted by an unknown...
# 2     National  On 14 March 2020, an IED planted by an unknown...
# 3        Other  On 14 March 2020, an unknown gunman set fire t...
# 4        Other  On 14 March 2020, an IED planted in a car by a...
#
#          fatalities     timestamp           iso3
# 0  #affected+killed           NaN  #country+code
# 1                 0  1.584396e+09            SYR
# 2                 0  1.584396e+09            SYR
# 3                 0  1.584396e+09            SYR
# 4                 1  1.584396e+09            SYR

# %%
print(conflict_syr.iloc[0,:])
# Out:
# data_id                                  NaN
# iso                                      NaN
# event_id_cnty                    #event+code
# event_id_no_cnty                         NaN
# event_date                    #date+occurred
# year                              #date+year
# time_precision                           NaN
# event_type                       #event+type
# sub_event_type                           NaN
# actor1                     #group+name+first
# assoc_actor_1        #group+name+first+assoc
# inter1                                   NaN
# actor2                    #group+name+second
# assoc_actor_2       #group+name+second+assoc
# inter2                                   NaN
# interaction                              NaN
# region                          #region+name
# country                        #country+name
# admin1                            #adm1+name
# admin2                            #adm2+name
# admin3                            #adm3+name
# location                           #loc+name
# latitude                            #geo+lat
# longitude                           #geo+lon
# geo_precision                            NaN
# source                          #meta+source
# source_scale                             NaN
# notes                           #description
# fatalities                  #affected+killed
# timestamp                                NaN
# iso3                           #country+code
# Name: 0, dtype: object

# %%
conflict_syr = conflict_syr.drop(0)

# %%
print(conflict_syr['year'].max())
print(conflict_syr['year'].min())
# Out:
# 2020
# 2017

# %%
null_cols = conflict_syr.isnull().sum()
null_cols
# Out:
# data_id                 0
# iso                     0
# event_id_cnty           0
# event_id_no_cnty        0
# event_date              0
# year                    0
# time_precision          0
# event_type              0
# sub_event_type          0
# actor1                  0
# assoc_actor_1       57825
# inter1                  0
# actor2              32623
# assoc_actor_2       67046
# inter2                  0
# interaction             0
# region                  0
# country                 0
# admin1                  0
# admin2                  0
# admin3                  0
# location                0
# latitude                0
# longitude               0
# geo_precision           0
# source                  0
# source_scale            0
# notes                   0
# fatalities              0
# timestamp               0
# iso3                    0
# dtype: int64

# %%
conflict_syr.shape
# Out:
# (74883, 31)

# %%
conflict_syr = conflict_syr.drop(['assoc_actor_1', 'assoc_actor_2' ], axis = 1)

# %%
conflict_syr.head()
# Out:
#      data_id    iso event_id_cnty  event_id_no_cnty  event_date  year  \
# 1  6993667.0  760.0      SYR76938           76938.0  2020-03-14  2020
# 2  6993669.0  760.0      SYR76939           76939.0  2020-03-14  2020
# 3  6993742.0  760.0      SYR76930           76930.0  2020-03-14  2020
# 4  6993746.0  760.0      SYR76937           76937.0  2020-03-14  2020
# 5  6993757.0  760.0      SYR76943           76943.0  2020-03-14  2020
#
#    time_precision                  event_type                 sub_event_type  \
# 1             1.0  Explosions/Remote violence  Remote explosive/landmine/IED
# 2             1.0  Explosions/Remote violence  Remote explosive/landmine/IED
# 3             1.0                     Battles                    Armed clash
# 4             1.0  Explosions/Remote violence  Remote explosive/landmine/IED
# 5             1.0                       Riots          Violent demonstration
#
#                              actor1  inter1  \
# 1  Unidentified Armed Group (Syria)     3.0
# 2  Unidentified Armed Group (Syria)     3.0
# 3  Unidentified Armed Group (Syria)     3.0
# 4  Unidentified Armed Group (Syria)     3.0
# 5                   Rioters (Syria)     5.0
#
#                                          actor2  inter2  interaction  \
# 1                                           NaN     0.0         30.0
# 2                                           NaN     0.0         30.0
# 3  QSD: Syrian Democratic Forces - Intelligence     2.0         23.0
# 4                        Operation Peace Spring     2.0         23.0
# 5                                           NaN     0.0         50.0
#
#         region country       admin1       admin2    admin3  location latitude  \
# 1  Middle East   Syria     Ar-Raqqa     Ar-Raqqa  Ar-Raqqa  Ar-Raqqa  35.9428
# 2  Middle East   Syria     Ar-Raqqa     Ar-Raqqa    Karama    Karama  35.8699
# 3  Middle East   Syria  Deir-ez-Zor  Deir-ez-Zor    Basira    Takihi  35.1751
# 4  Middle East   Syria       Aleppo       Al Bab  Ar-Ra'ee  Ar-Ra'ee  36.6125
# 5  Middle East   Syria        Idleb        Ariha     Ariha     Ariha  35.8140
#
#   longitude  geo_precision source source_scale  \
# 1   39.0519            1.0   SHAM     National
# 2   39.2813            2.0   SHAM     National
# 3   40.4547            2.0   SOHR        Other
# 4   37.4464            1.0   SOHR        Other
# 5   36.6102            2.0   SOHR        Other
#
#                                                notes fatalities     timestamp  \
# 1  On 14 March 2020, an IED planted by an unknown...          0  1.584396e+09
# 2  On 14 March 2020, an IED planted by an unknown...          0  1.584396e+09
# 3  On 14 March 2020, an unknown gunman set fire t...          0  1.584396e+09
# 4  On 14 March 2020, an IED planted in a car by a...          1  1.584396e+09
# 5  On 14 March 2020, people of Idlib have been st...          0  1.584396e+09
#
#   iso3
# 1  SYR
# 2  SYR
# 3  SYR
# 4  SYR
# 5  SYR

# %%
conflict_syr['fatalities'].count()
# Out:
# 74883

# %%
conflict_syr.aggregate({"fatalities":['sum']})
# Out:
#                                             fatalities
# sum  0001000000110005300300000000100002000000000011...

# %%
conflict_syr.dtypes
# Out:
# data_id             float64
# iso                 float64
# event_id_cnty        object
# event_id_no_cnty    float64
# event_date           object
# year                 object
# time_precision      float64
# event_type           object
# sub_event_type       object
# actor1               object
# inter1              float64
# actor2               object
# inter2              float64
# interaction         float64
# region               object
# country              object
# admin1               object
# admin2               object
# admin3               object
# location             object
# latitude             object
# longitude            object
# geo_precision       float64
# source               object
# source_scale         object
# notes                object
# fatalities           object
# timestamp           float64
# iso3                 object
# dtype: object

# %%
conflict_syr = conflict_syr.astype({"notes": str, "fatalities": int})

# %%
conflict_syr.aggregate({"fatalities":['sum']})
# Out:
#      fatalities
# sum      102582

# %%
print(conflict_syr.country.unique())
print(conflict_syr.iso.unique())
print(conflict_syr.iso3.unique())
print(conflict_syr.region.unique())
# Out:
# ['Syria']
# [760.]
# ['SYR']
# ['Middle East']

# %%
syr_data = conflict_syr.drop(['iso', 'country', 'region', 'iso3','event_id_cnty','event_id_no_cnty'], axis = 1)

# %%
syr_data[['data_id', 'time_precision', 'inter1','inter2', 'interaction', 'geo_precision']] = syr_data[['data_id', 'time_precision', 'inter1','inter2', 'interaction', 'geo_precision']].astype(int)
#df[['one', 'two', 'three']] = df[['one', 'two', 'three']].astype(str)

# %%
syr_data.dtypes
# notes is still an object but it might not even be a problem.
# Out:
# data_id             int64
# event_date         object
# year               object
# time_precision      int64
# event_type         object
# sub_event_type     object
# actor1             object
# inter1              int64
# actor2             object
# inter2              int64
# interaction         int64
# admin1             object
# admin2             object
# admin3             object
# location           object
# latitude           object
# longitude          object
# geo_precision       int64
# source             object
# source_scale       object
# notes              object
# fatalities          int64
# timestamp         float64
# dtype: object

# %% [markdown]
# ### Text analysis
#
# The column 'notes' has a short description for each event that occurred. This is the data I want to analyse.
#
# [StackOverflow select string](https://stackoverflow.com/questions/11350770/select-by-partial-string-from-a-pandas-dataframe)<br>
# [StackOverflow new column based on string selection](https://stackoverflow.com/questions/43399435/new-column-based-on-specific-string-info-from-two-different-columns-python-panda)<br>
# [StackOverflow contains statement](https://stackoverflow.com/questions/54484435/python-create-new-column-with-condition-and-contains-statement)<br>
#
# **Step 1:** Create two separate columns counting mentions of men and women (separately).<br>
# **Step 2:** Find a way to get associative words for each of these (TextBlob has a noun_phrases function, maybe that will get me somewhere)

# %%
#syr_data[['men' in x for x in syr_data['notes']]]

#def count_men(row):
 #   if syr_data[['men' in x for x in syr_data['notes']]]:
  #      val = 1
   # else:
    #    val = 0
    #return val

#syr_data['men'] = syr_data.apply(count_men, axis=1)

#syr_data['men'] = np.where(syr_data.notes.str.contains(r'\bmen\b'), 1, else 0)

#syr_data['men'] = syr_data['notes'].apply(lambda x : 1 if x.str.contains(r'\bmen\b') else 0)

#print(syr_data)

# %%
syr_data['men'] = np.where(syr_data['notes'].str.contains('\\b(?:men|man|male|males)\\b'), 1, 0)

# %%
syr_data.head()
# Out:
#    data_id  event_date  year  time_precision                  event_type  \
# 1  6993667  2020-03-14  2020               1  Explosions/Remote violence
# 2  6993669  2020-03-14  2020               1  Explosions/Remote violence
# 3  6993742  2020-03-14  2020               1                     Battles
# 4  6993746  2020-03-14  2020               1  Explosions/Remote violence
# 5  6993757  2020-03-14  2020               1                       Riots
#
#                   sub_event_type                            actor1  inter1  \
# 1  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 2  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 3                    Armed clash  Unidentified Armed Group (Syria)       3
# 4  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 5          Violent demonstration                   Rioters (Syria)       5
#
#                                          actor2  inter2  interaction  \
# 1                                           NaN       0           30
# 2                                           NaN       0           30
# 3  QSD: Syrian Democratic Forces - Intelligence       2           23
# 4                        Operation Peace Spring       2           23
# 5                                           NaN       0           50
#
#         admin1       admin2    admin3  location latitude longitude  \
# 1     Ar-Raqqa     Ar-Raqqa  Ar-Raqqa  Ar-Raqqa  35.9428   39.0519
# 2     Ar-Raqqa     Ar-Raqqa    Karama    Karama  35.8699   39.2813
# 3  Deir-ez-Zor  Deir-ez-Zor    Basira    Takihi  35.1751   40.4547
# 4       Aleppo       Al Bab  Ar-Ra'ee  Ar-Ra'ee  36.6125   37.4464
# 5        Idleb        Ariha     Ariha     Ariha  35.8140   36.6102
#
#    geo_precision source source_scale  \
# 1              1   SHAM     National
# 2              2   SHAM     National
# 3              2   SOHR        Other
# 4              1   SOHR        Other
# 5              2   SOHR        Other
#
#                                                notes  fatalities  \
# 1  On 14 March 2020, an IED planted by an unknown...           0
# 2  On 14 March 2020, an IED planted by an unknown...           0
# 3  On 14 March 2020, an unknown gunman set fire t...           0
# 4  On 14 March 2020, an IED planted in a car by a...           1
# 5  On 14 March 2020, people of Idlib have been st...           0
#
#       timestamp  men
# 1  1.584396e+09    0
# 2  1.584396e+09    0
# 3  1.584396e+09    0
# 4  1.584396e+09    0
# 5  1.584396e+09    0

# %%
print(syr_data.men.unique())
syr_data['men'].value_counts()
# Out:
# [0 1]
# 0    71123
# 1     3760
# Name: men, dtype: int64

# %%
syr_data['women'] = np.where(syr_data['notes'].str.contains('\\b(?:women|woman|female|females)\\b'), 1, 0)
syr_data.head()
# Out:
#    data_id  event_date  year  time_precision                  event_type  \
# 1  6993667  2020-03-14  2020               1  Explosions/Remote violence
# 2  6993669  2020-03-14  2020               1  Explosions/Remote violence
# 3  6993742  2020-03-14  2020               1                     Battles
# 4  6993746  2020-03-14  2020               1  Explosions/Remote violence
# 5  6993757  2020-03-14  2020               1                       Riots
#
#                   sub_event_type                            actor1  inter1  \
# 1  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 2  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 3                    Armed clash  Unidentified Armed Group (Syria)       3
# 4  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 5          Violent demonstration                   Rioters (Syria)       5
#
#                                          actor2  inter2  interaction  \
# 1                                           NaN       0           30
# 2                                           NaN       0           30
# 3  QSD: Syrian Democratic Forces - Intelligence       2           23
# 4                        Operation Peace Spring       2           23
# 5                                           NaN       0           50
#
#         admin1       admin2    admin3  location latitude longitude  \
# 1     Ar-Raqqa     Ar-Raqqa  Ar-Raqqa  Ar-Raqqa  35.9428   39.0519
# 2     Ar-Raqqa     Ar-Raqqa    Karama    Karama  35.8699   39.2813
# 3  Deir-ez-Zor  Deir-ez-Zor    Basira    Takihi  35.1751   40.4547
# 4       Aleppo       Al Bab  Ar-Ra'ee  Ar-Ra'ee  36.6125   37.4464
# 5        Idleb        Ariha     Ariha     Ariha  35.8140   36.6102
#
#    geo_precision source source_scale  \
# 1              1   SHAM     National
# 2              2   SHAM     National
# 3              2   SOHR        Other
# 4              1   SOHR        Other
# 5              2   SOHR        Other
#
#                                                notes  fatalities  \
# 1  On 14 March 2020, an IED planted by an unknown...           0
# 2  On 14 March 2020, an IED planted by an unknown...           0
# 3  On 14 March 2020, an unknown gunman set fire t...           0
# 4  On 14 March 2020, an IED planted in a car by a...           1
# 5  On 14 March 2020, people of Idlib have been st...           0
#
#       timestamp  men  women
# 1  1.584396e+09    0      0
# 2  1.584396e+09    0      0
# 3  1.584396e+09    0      0
# 4  1.584396e+09    0      0
# 5  1.584396e+09    0      0

# %%
syr_data['women'].value_counts()
# Out:
# 0    72729
# 1     2154
# Name: women, dtype: int64

# %% [markdown]
# #### For the love of all that is good, please remember your research question and your goal!
#
# Goal: to approximate gender disaggregated data through notes/mentions/news headlines (the latter refers to the DRC dataset).
#
# Question: Can we approximate gender disaggregation for vulnerability in violent events?

# %%
def extract_nouns(text):
    blob = TextBlob(text)
    return [word for word in blob.noun_phrases]

syr_data['nouns'] = syr_data['notes'].apply(extract_nouns)

# %%
syr_data.head()
# Out:
#    data_id  event_date  year  time_precision                  event_type  \
# 1  6993667  2020-03-14  2020               1  Explosions/Remote violence
# 2  6993669  2020-03-14  2020               1  Explosions/Remote violence
# 3  6993742  2020-03-14  2020               1                     Battles
# 4  6993746  2020-03-14  2020               1  Explosions/Remote violence
# 5  6993757  2020-03-14  2020               1                       Riots
#
#                   sub_event_type                            actor1  inter1  \
# 1  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 2  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 3                    Armed clash  Unidentified Armed Group (Syria)       3
# 4  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 5          Violent demonstration                   Rioters (Syria)       5
#
#                                          actor2  inter2  interaction  \
# 1                                           NaN       0           30
# 2                                           NaN       0           30
# 3  QSD: Syrian Democratic Forces - Intelligence       2           23
# 4                        Operation Peace Spring       2           23
# 5                                           NaN       0           50
#
#         admin1       admin2    admin3  location latitude longitude  \
# 1     Ar-Raqqa     Ar-Raqqa  Ar-Raqqa  Ar-Raqqa  35.9428   39.0519
# 2     Ar-Raqqa     Ar-Raqqa    Karama    Karama  35.8699   39.2813
# 3  Deir-ez-Zor  Deir-ez-Zor    Basira    Takihi  35.1751   40.4547
# 4       Aleppo       Al Bab  Ar-Ra'ee  Ar-Ra'ee  36.6125   37.4464
# 5        Idleb        Ariha     Ariha     Ariha  35.8140   36.6102
#
#    geo_precision source source_scale  \
# 1              1   SHAM     National
# 2              2   SHAM     National
# 3              2   SOHR        Other
# 4              1   SOHR        Other
# 5              2   SOHR        Other
#
#                                                notes  fatalities  \
# 1  On 14 March 2020, an IED planted by an unknown...           0
# 2  On 14 March 2020, an IED planted by an unknown...           0
# 3  On 14 March 2020, an unknown gunman set fire t...           0
# 4  On 14 March 2020, an IED planted in a car by a...           1
# 5  On 14 March 2020, people of Idlib have been st...           0
#
#       timestamp  men  women                                              nouns
# 1  1.584396e+09    0      0                      [march, ied, tawsi, ar-raqqa]
# 2  1.584396e+09    0      0  [march, ied, qatirji, oil trucks, minkhar, kar...
# 3  1.584396e+09    0      0  [march, unknown gunman, military vehicle, qsd,...
# 4  1.584396e+09    0      0                     [march, ied, ar-ra'ee, aleppo]
# 5  1.584396e+09    0      0  [march, idlib, jisr ariha, aleppo-latakia, int...

# %%
# For future reference: 
# https://stackoverflow.com/questions/56980515/how-to-extract-all-adjectives-from-a-strings-of-text-in-a-pandas-dataframe
# https://stackoverflow.com/questions/53155803/textblob-for-extracting-noun-phrases-wordlist-issue

# %%
print(syr_data['nouns'].str.len().max())
print(syr_data['nouns'].str.len().min())
# Out:
# 83
# 0

# %%
def get_verbs(text):
    tags = ["VB", "VBZ", "VBP","VBD","VBN","VBG"]
    blob = TextBlob(text)
    return [ word for (word,tag) in blob.tags if tag in tags]

syr_data['verbs'] = syr_data['notes'].apply(get_verbs)

# %%
syr_data['children'] = np.where(syr_data['notes'].str.contains('\\b(?:child|children)\\b'), 1, 0)
syr_data['civilians'] = np.where(syr_data['notes'].str.contains('\\b(?:civilian|civilians)\\b'), 1, 0)

# %%
syr_data.head()
# Out:
#    data_id  event_date  year  time_precision                  event_type  \
# 1  6993667  2020-03-14  2020               1  Explosions/Remote violence
# 2  6993669  2020-03-14  2020               1  Explosions/Remote violence
# 3  6993742  2020-03-14  2020               1                     Battles
# 4  6993746  2020-03-14  2020               1  Explosions/Remote violence
# 5  6993757  2020-03-14  2020               1                       Riots
#
#                   sub_event_type                            actor1  inter1  \
# 1  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 2  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 3                    Armed clash  Unidentified Armed Group (Syria)       3
# 4  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 5          Violent demonstration                   Rioters (Syria)       5
#
#                                          actor2  inter2  interaction  \
# 1                                           NaN       0           30
# 2                                           NaN       0           30
# 3  QSD: Syrian Democratic Forces - Intelligence       2           23
# 4                        Operation Peace Spring       2           23
# 5                                           NaN       0           50
#
#         admin1       admin2    admin3  location latitude longitude  \
# 1     Ar-Raqqa     Ar-Raqqa  Ar-Raqqa  Ar-Raqqa  35.9428   39.0519
# 2     Ar-Raqqa     Ar-Raqqa    Karama    Karama  35.8699   39.2813
# 3  Deir-ez-Zor  Deir-ez-Zor    Basira    Takihi  35.1751   40.4547
# 4       Aleppo       Al Bab  Ar-Ra'ee  Ar-Ra'ee  36.6125   37.4464
# 5        Idleb        Ariha     Ariha     Ariha  35.8140   36.6102
#
#    geo_precision source source_scale  \
# 1              1   SHAM     National
# 2              2   SHAM     National
# 3              2   SOHR        Other
# 4              1   SOHR        Other
# 5              2   SOHR        Other
#
#                                                notes  fatalities  \
# 1  On 14 March 2020, an IED planted by an unknown...           0
# 2  On 14 March 2020, an IED planted by an unknown...           0
# 3  On 14 March 2020, an unknown gunman set fire t...           0
# 4  On 14 March 2020, an IED planted in a car by a...           1
# 5  On 14 March 2020, people of Idlib have been st...           0
#
#       timestamp  men  women  \
# 1  1.584396e+09    0      0
# 2  1.584396e+09    0      0
# 3  1.584396e+09    0      0
# 4  1.584396e+09    0      0
# 5  1.584396e+09    0      0
#
#                                                nouns  \
# 1                      [march, ied, tawsi, ar-raqqa]
# 2  [march, ied, qatirji, oil trucks, minkhar, kar...
# 3  [march, unknown gunman, military vehicle, qsd,...
# 4                     [march, ied, ar-ra'ee, aleppo]
# 5  [march, idlib, jisr ariha, aleppo-latakia, int...
#
#                                               verbs  children  civilians
# 1               [planted, exploded, were, reported]         0          0
# 2               [planted, exploded, were, reported]         0          0
# 3                 [set, affiliated, were, reported]         0          0
# 4     [planted, exploded, killing, backed, injured]         0          1
# 5  [have, been, holding, overlooking, cut, setting]         0          0

# %% [markdown]
# I'm going down a NLP path now, and that wasn't the original intention.
#
# I'm going to see if I can make some of the descriptive data numeral so I can analyse it better.
#
# **Interesting columns:**<br>
# 1) type of event<br>
# 2) sub-type<br>
# 3) Actors have already been given numeral values in the original dataframe, so I'll take over their codebook here.

# %%
print(len(conflict_syr.event_type.unique()))
print(len(conflict_syr.sub_event_type.unique()))
print(conflict_syr.event_type.unique())
print(conflict_syr.sub_event_type.unique())
# Out:
# 6
# 25
# ['Explosions/Remote violence' 'Battles' 'Riots' 'Strategic developments'
#  'Violence against civilians' 'Protests']
# ['Remote explosive/landmine/IED' 'Armed clash' 'Violent demonstration'
#  'Shelling/artillery/missile attack' 'Disrupted weapons use'
#  'Change to group/activity' 'Attack' 'Looting/property destruction'
#  'Headquarters or base established' 'Peaceful protest' 'Air/drone strike'
#  'Non-violent transfer of territory' 'Arrests'
#  'Abduction/forced disappearance' 'Other' 'Government regains territory'
#  'Non-state actor overtakes territory' 'Agreement' 'Grenade'
#  'Mob violence' 'Suicide bomb' 'Excessive force against protesters'
#  'Protest with intervention' 'Sexual violence' 'Chemical weapon']

# %% [markdown]
# [StackOverflow Assign id](https://stackoverflow.com/questions/33283086/assign-unique-id-to-columns-pandas-data-frame)

# %%
event_types = conflict_syr.event_type.unique()
event_types

event_types_num = pd.Series(np.arange(len(event_types)), event_types)
print(event_types_num)

syr_data[['event_id']] = syr_data[['event_type']].applymap(event_types_num.get)

#df['Value'] = df['Venue Category'].map(d)
# Save event_id to codebook
# Out:
# Explosions/Remote violence    0
# Battles                       1
# Riots                         2
# Strategic developments        3
# Violence against civilians    4
# Protests                      5
# dtype: int64

# %%
syr_data.head()
# Out:
#    data_id  event_date  year  time_precision                  event_type  \
# 1  6993667  2020-03-14  2020               1  Explosions/Remote violence
# 2  6993669  2020-03-14  2020               1  Explosions/Remote violence
# 3  6993742  2020-03-14  2020               1                     Battles
# 4  6993746  2020-03-14  2020               1  Explosions/Remote violence
# 5  6993757  2020-03-14  2020               1                       Riots
#
#                   sub_event_type                            actor1  inter1  \
# 1  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 2  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 3                    Armed clash  Unidentified Armed Group (Syria)       3
# 4  Remote explosive/landmine/IED  Unidentified Armed Group (Syria)       3
# 5          Violent demonstration                   Rioters (Syria)       5
#
#                                          actor2  inter2  interaction  \
# 1                                           NaN       0           30
# 2                                           NaN       0           30
# 3  QSD: Syrian Democratic Forces - Intelligence       2           23
# 4                        Operation Peace Spring       2           23
# 5                                           NaN       0           50
#
#         admin1       admin2    admin3  location latitude longitude  \
# 1     Ar-Raqqa     Ar-Raqqa  Ar-Raqqa  Ar-Raqqa  35.9428   39.0519
# 2     Ar-Raqqa     Ar-Raqqa    Karama    Karama  35.8699   39.2813
# 3  Deir-ez-Zor  Deir-ez-Zor    Basira    Takihi  35.1751   40.4547
# 4       Aleppo       Al Bab  Ar-Ra'ee  Ar-Ra'ee  36.6125   37.4464
# 5        Idleb        Ariha     Ariha     Ariha  35.8140   36.6102
#
#    geo_precision source source_scale  \
# 1              1   SHAM     National
# 2              2   SHAM     National
# 3              2   SOHR        Other
# 4              1   SOHR        Other
# 5              2   SOHR        Other
#
#                                                notes  fatalities  \
# 1  On 14 March 2020, an IED planted by an unknown...           0
# 2  On 14 March 2020, an IED planted by an unknown...           0
# 3  On 14 March 2020, an unknown gunman set fire t...           0
# 4  On 14 March 2020, an IED planted in a car by a...           1
# 5  On 14 March 2020, people of Idlib have been st...           0
#
#       timestamp  men  women  \
# 1  1.584396e+09    0      0
# 2  1.584396e+09    0      0
# 3  1.584396e+09    0      0
# 4  1.584396e+09    0      0
# 5  1.584396e+09    0      0
#
#                                                nouns  \
# 1                      [march, ied, tawsi, ar-raqqa]
# 2  [march, ied, qatirji, oil trucks, minkhar, kar...
# 3  [march, unknown gunman, military vehicle, qsd,...
# 4                     [march, ied, ar-ra'ee, aleppo]
# 5  [march, idlib, jisr ariha, aleppo-latakia, int...
#
#                                               verbs  children  civilians  \
# 1               [planted, exploded, were, reported]         0          0
# 2               [planted, exploded, were, reported]         0          0
# 3                 [set, affiliated, were, reported]         0          0
# 4     [planted, exploded, killing, backed, injured]         0          1
# 5  [have, been, holding, overlooking, cut, setting]         0          0
#
#    event_id
# 1         0
# 2         0
# 3         1
# 4         0
# 5         2

# %%
df1 = syr_data[['event_type', 'notes', 'fatalities','men','women','children','civilians','nouns','verbs']]
df1.head(10)
# Out:
#                     event_type  \
# 1   Explosions/Remote violence
# 2   Explosions/Remote violence
# 3                      Battles
# 4   Explosions/Remote violence
# 5                        Riots
# 6   Explosions/Remote violence
# 7                      Battles
# 8   Explosions/Remote violence
# 9       Strategic developments
# 10                     Battles
#
#                                                 notes  fatalities  men  women  \
# 1   On 14 March 2020, an IED planted by an unknown...           0    0      0
# 2   On 14 March 2020, an IED planted by an unknown...           0    0      0
# 3   On 14 March 2020, an unknown gunman set fire t...           0    0      0
# 4   On 14 March 2020, an IED planted in a car by a...           1    0      0
# 5   On 14 March 2020, people of Idlib have been st...           0    0      0
# 6   On 14 March 2020, an IED planted in a car by a...           0    0      0
# 7   On 14 March 2020, an exchange of shelling betw...           0    0      0
# 8   On 14 March 2020, opposition rebels shelled th...           0    0      0
# 9   Interception: On 14 March 2020, air defenses i...           0    0      0
# 10  On 14 March 2020, exchange of fire with medium...           0    0      0
#
#     children  civilians                                              nouns  \
# 1          0          0                      [march, ied, tawsi, ar-raqqa]
# 2          0          0  [march, ied, qatirji, oil trucks, minkhar, kar...
# 3          0          0  [march, unknown gunman, military vehicle, qsd,...
# 4          0          1                     [march, ied, ar-ra'ee, aleppo]
# 5          0          0  [march, idlib, jisr ariha, aleppo-latakia, int...
# 6          1          1                  [march, ied, raju, afrin, aleppo]
# 7          0          0  [march, turkish forces, ops, regime forces, sy...
# 8          0          0   [march, opposition rebels, al-qardaha, lattakia]
# 9          0          0  [interception, march, air defenses, lattakia, ...
# 10         0          0  [march, medium-range machine guns, regime forc...
#
#                                                 verbs
# 1                 [planted, exploded, were, reported]
# 2                 [planted, exploded, were, reported]
# 3                   [set, affiliated, were, reported]
# 4       [planted, exploded, killing, backed, injured]
# 5    [have, been, holding, overlooking, cut, setting]
# 6            [planted, exploded, injuring, including]
# 7   [shelling, supported, backed, are, operating, ...
# 8                           [shelled, were, reported]
# 9   [intercepted, is, known, were, intercepting, f...
# 10                             [took, were, reported]

# %%
print(conflict_syr.location.unique())
print(len(conflict_syr.location.unique()))
# Not assigning numeral values to locations. 
print(conflict_syr.admin1.unique())
print(len(conflict_syr.admin1.unique()))
print(conflict_syr.admin2.unique())
print(len(conflict_syr.admin2.unique()))
print(conflict_syr.admin3.unique())
print(len(conflict_syr.admin3.unique()))

#Due to time constraints and the amount of data here, I won't be focusing on precise locations right now. 
# I might do something with Admin1 if time allows, because that has 14 unique values. I may be able to distinguish between front-line or conflict-heavy areas and 'calmer' areas at the time of the event.
# Out:
# ['Ar-Raqqa' 'Karama' 'Takihi' ... 'Al-Nasiriyyah Military Airport'
#  'Himarayn' 'Rasm Abbud']
# 3328
# ['Ar-Raqqa' 'Deir-ez-Zor' 'Aleppo' 'Idleb' 'Al-Hasakeh' 'Lattakia' 'Hama'
#  'Damascus' "Dar'a" 'Homs' 'Rural Damascus' 'As-Sweida' 'Quneitra'
#  'Tartous']
# 14
# ['Ar-Raqqa' 'Deir-ez-Zor' 'Al Bab' 'Ariha' 'Afrin' 'Ras Al Ain'
#  'Al-Qardaha' 'Jablah' 'Idleb' 'Al Mayadin' 'Al-Hasakeh' 'Harim'
#  'Al-Haffa' 'As-Suqaylabiyah' "A'zaz" 'Damascus' 'Tell Abiad' "Dar'a"
#  "Al Ma'ra" 'Homs' 'Jebel Saman' 'Abu Kamal' 'Quamishli' 'Duma' 'At Tall'
#  'Rural Damascus' "Izra'" 'Al-Malikeyyeh' 'As-Sweida' 'Lattakia' 'Hama'
#  'Jisr-Ash-Shugur' 'Ar-Rastan' 'Menbij' 'Ath-Thawrah' 'Quneitra'
#  'Al-Qusayr' 'As-Sanamayn' 'Ain Al Arab' 'Jarablus' 'Qatana' 'As-Safira'
#  'Muhradah' 'Masyaf' 'Tadmor' 'An Nabk' 'Darayya' 'Shahba' 'Al Makhrim'
#  'Yabroud' 'As-Salamiyeh' 'Al Qutayfah' 'Tartous' 'Az-Zabdani'
#  'Tall Kalakh' 'Salkhad' 'Banyas' 'Al Fiq']
# 58
# ['Ar-Raqqa' 'Karama' 'Basira' "Ar-Ra'ee" 'Ariha' 'Afrin' 'Ras Al Ain'
#  'Al-Qardaha' 'Jablah' 'Saraqab' 'Thiban' 'Hole' 'Tal Tamer' 'Dana'
#  'Kansaba' 'Ziyara' 'Maadan' 'Suran' 'Idleb' 'Damascus' 'Al Mayadin'
#  'Ein Issa' "Dar'a" 'Kafr Nobol' 'Al-Hasakeh' 'Tell Abiad' 'Taldu'
#  'Atareb' 'Salqin' 'Abu Kamal' 'Suluk' 'Quamishli' 'Duma' 'Sidnaya'
#  "A'zaz" 'Kafr Batna' 'Jebel Saman' 'Mzeireb' 'Arbin' 'Jasim' 'Susat'
#  'Deir-ez-Zor' 'Al-Malikeyyeh' 'Tall Refaat' 'As-Sweida' 'Lattakia' 'Hama'
#  'Jisr-Ash-Shugur' 'Al Bab' 'Tabni' 'Talbiseh' 'Darbasiyah' 'Daret Azza'
#  'Shadadah' 'Sharan' 'Kisreh' 'Menbij' 'Maaret Tamsrin' 'Ehsem' 'Babella'
#  'As-Suqaylabiyah' 'Harbanifse' 'Hrak' 'Al-Thawrah' 'Mansura'
#  'Al-Khashniyyeh' 'Raqama' 'Al-Qusayr' 'Quneitra' "Mare'" 'Hajin'
#  'Jandairis' 'Sarmin' 'Nabul' 'Kisweh' 'Homs' 'Haritan' 'Tadaf' 'Bennsh'
#  "Ma'arrat An Nu'man" 'Badama' 'As-Sanamayn' 'Kherbet Ghazala' 'Mseifra'
#  'Ash-Shajara' 'Madiq Castle' 'Mhambal' 'Ain al Arab' 'Teftnaz' 'Shat-ha'
#  'Jarablus' "Sa'sa'" "A'rima" 'Busra Esh-Sham' 'Jaramana' 'Salanfa' 'Nawa'
#  'Sur' 'As-Safira' 'Zarbah' 'Qodsayya' 'Khan Arnaba' 'Eastern Kwaires'
#  'Markada' 'Aghtrin' 'Qatana' 'Khan Shaykun' 'Karnaz' 'Heish' 'Masyaf'
#  'Haran Alawameed' 'Amuda' 'Raju' 'Sabka' 'Bulbul' 'Harim' 'Ghandorah'
#  'Nashabiyeh' 'Khasham' 'Muhradah' "Da'el" 'Sokhneh' 'Abul Thohur'
#  'Qourqeena' 'Jeb Ramleh' 'An Nabk' 'Masmiyyeh' 'Hadher' "Ma'btali"
#  'Tadmor' 'Sahnaya' 'At Tall' "Izra'" 'Qudsiya' "Mazra'a" 'Lower Shyookh'
#  'Tell Salhib' 'Muhasan' 'Janudiyeh' 'Kafr Zeita' 'Sanjar' 'Areesheh'
#  'Tal Hmis' 'Tassil' 'Kafr Takharim' 'Armanaz' 'Tamanaah' 'Tall Ed-daman'
#  'Darkosh' 'Shahba' 'Ariqa' 'Rankus' 'Qaryatein' "Rabee'a" 'Qahtaniyyeh'
#  'Qastal Maaf' 'Sheikh El-Hadid' 'Ashara' 'Jalaa' 'Khanaser' 'Ghabagheb'
#  "Be'r Al-Hulo Al-Wardeyyeh" 'Jeb Ej-Jarrah' 'Bait Jan' 'Markaz Darayya'
#  'Jizeh' 'Assal al Ward' 'As-Saan' 'Raheiba' 'Sheikh Miskine' 'Maliha'
#  'Jurneyyeh' 'Harasta' 'Sarin' 'Dhameer' 'Mashnaf' "Ya'robiyah" 'Jirud'
#  'As-Salamiyeh' 'Sabe Byar' 'Tartous' 'Maskana' 'Az-Zabdani' 'Al-Khafsa'
#  'Jawadiyah' 'Ar-Rastan' 'Little Sura' 'Dimas' 'Oqeirbat' 'Hamra'
#  'Deir Attiyeh' 'Yabroud' 'Abu Qalqal' 'Al-Haffa' 'Ein Elfijeh' 'Katzrin'
#  'Kasab' 'Al Qutayfah' 'Saboura' 'Tall Kalakh' 'Qarayya' 'Masaada'
#  'Rasm Haram El-Imam' 'Ein Elniser' 'Eastern Bari' 'Wadi El-oyoun' 'ff'
#  'Banyas' 'Ath-Thawrah' 'Shaqa' 'Dayr Hafir' 'Hajar Aswad' 'Oj'
#  'Al Makhrim' 'Hadideh' 'Beit Yashout' 'Madaya' 'Nasra' 'Farqalas'
#  'Hawash' 'Hasyaa' 'Hajeb' 'Banan' 'Western Ghota' 'Mahin' 'Jinderes'
#  'Ein Halaqim' 'Fiq' 'Qabu' 'Shin' 'Esal Al Ward' 'Ain Al Arab' 'Thibeen'
#  'Sarghaya' 'Kherbet Tin Noor']
# 235

# %% [markdown]
# ### Final cleaning:
#
# While all these columns are massively interesting and I would love to analyse all of them, I am creating a stripped copy of the current dataframe containing only columns that are relevant to my current goal. This is subject to change (as I might need more data down the line, but right now I notice that keeping all the current columns is distracting.

# %%
syr_data_new = syr_data.filter(['year', 'event_type', 'sub_event_type', 'actor1', 'inter1', 'actor2', 'inter2', 'interaction', 'admin1', 'admin2', 'admin3', 'location', 'notes', 'fatalities', 'men' , 'women', 'nouns', 'verbs', 'event_id', 'children', 'civilians'], axis=1)

# %%
#with open('../data/HDX-data/syr/conflict_data_syr.csv') as f:
    print(f)

# %%
#syr_data.to_csv('../data/syr_data_cleaned.csv', encoding='utf-8', index=False)

# %%
#syr_data_new.to_csv('../data/syr_data_new.csv', encoding='utf-8', index=False)
